# %%
#auto reloader
# %load_ext autoreload
# %autoreload 2

# %%
from processor import StudentAssignmentProcessor
processor = StudentAssignmentProcessor('response.xlsx', 'classlist.xlsx')

# %%
processor.process(min_sector_size=0, max_group_size=16, min_group_size=4, response_file='input/response.xlsx', classlist_file='input/classlist.xlsx')

# %%
#processor.process(min_sector_size=0)
