# %%
#auto reloader
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from processor import StudentAssignmentProcessor

# %%
# --- Step 3: Configure File Paths ---
# IMPORTANT: Update these variables with the correct paths to your Excel files.

# Example for files in the same directory as the notebook:
# RESPONSE_FILE = 'student_responses.xlsx' 

# Example for files in a sub-folder named 'data':
RESPONSE_FILE = 'input/responses.xlsx'
CLASSLIST_FILE = 'input/classlist.xlsx'
SPEAKER_FILE = 'input/Speaker_list.xlsx'

# You can also specify the sheet name in the speaker file if it's not the first one.
SPEAKER_SHEET_NAME = "Form Responses 1" # 0 means the first sheet. You can also use 'Sheet1', for example.

# Define the name for the output file.
# A timestamp will be added automatically if you leave it as None.
#OUTPUT_FILE = 'output/final_assignments.xlsx'

# --- Verification Step (Optional but Recommended) ---
# This checks if the files exist before you run the main process.
all_files_exist = True
for f in [RESPONSE_FILE, CLASSLIST_FILE, SPEAKER_FILE]:
    if not os.path.exists(f):
        print(f"❌ ERROR: File not found at '{f}'")
        all_files_exist = False

if all_files_exist:
    print("✅ All input files found. Ready to proceed.")
# Out:
# ✅ All input files found. Ready to proceed.

# %%
# --- Step 4: Initialize and Run the Processor ---

# Only proceed if the file check in the previous cell was successful.
if all_files_exist:
    try:
        print("Initializing the assignment processor...")
        
        # Create an instance of the processor with your file paths.
        processor = StudentAssignmentProcessor(
            response_file=RESPONSE_FILE,
            classlist_file=CLASSLIST_FILE,
            speaker_file=SPEAKER_FILE
        )
        
        print("\nStarting the assignment process... This may take a moment.")
        
        # Run the main process.
        # It will read the files, perform the assignments and grouping, and write the output Excel file.
        processor.process( 
            speaker_sheet_name=SPEAKER_SHEET_NAME
        )
        
        print("-" * 50)
        print(f"🎉 Success! The process completed.")
        print(f"The output file has been saved to: '{ "None specified, check default location"}'")
        print("-" * 50)

    except (FileNotFoundError, KeyError) as e:
        # Catches errors related to missing files or incorrect column names.
        print("-" * 50)
        print(f"❌ ERROR: Could not complete processing.")
        print(f"Please check that your file paths are correct and that the required columns exist in your Excel files.")
        print(f"Details: {e}")
        print("-" * 50)
        
    except Exception as e:
        # Catches any other unexpected errors.
        print(f"An unexpected error occurred: {e}")
# Out:
# 2025-11-03 23:54:02,227 - INFO - [IN __init__] - Initializing StudentAssignmentProcessor...
# 2025-11-03 23:54:02,231 - INFO - [IN __init__] - Initialization complete.
# 2025-11-03 23:54:02,235 - INFO - [IN process] - Starting main processing workflow...
# 2025-11-03 23:54:02,237 - INFO - [IN _load_speaker_data] - Loading speaker data from 'input/Speaker_list.xlsx'...
# 2025-11-03 23:54:02,294 - INFO - [IN _load_speaker_data] - Speaker counts loaded successfully: {'Allied Health (PT, OT, RT)': 2, 'Architecture': 1, 'Arts': 0, 'Banking & Finance': 3, 'Computer Science': 2, 'Education': 2, 'Engineering': 1, 'Law': 1, 'Medical': 2, 'Social Science & Social Work': 1}
# 2025-11-03 23:54:02,296 - INFO - [IN _load_speaker_data] - Speaker names loaded successfully: {'Banking & Finance': ['Speaker 1', 'Speaker 2', 'Speaker 3'], 'Education': ['Speaker 1', 'Speaker 2'], 'Allied Health (PT, OT, RT)': ['Speaker 1', 'Speaker 2'], 'Engineering': ['Speaker 1'], 'Medical': ['Speaker 1', 'Speaker 2'], 'Computer Science': ['Speaker 1', 'Speaker 2'], 'Social Science & Social Work': ['Speaker 1'], 'Architecture': ['Speaker 1'], 'Law': ['Speaker 1']}
# 2025-11-03 23:54:02,411 - INFO - [IN process] - Loading and preparing class list files...
# Initializing the assignment processor...
#
# Starting the assignment process... This may take a moment.
# 2025-11-03 23:54:03,483 - INFO - [IN _merge_responses_with_classlists] - Merging student responses with class lists...
# 2025-11-03 23:54:03,495 - INFO - [IN _merge_responses_with_classlists] - Merge complete.
# 2025-11-03 23:54:03,496 - INFO - [IN _extract_sectors] - Extracting sector preferences...
# 2025-11-03 23:54:03,498 - INFO - [IN _extract_sectors] - Sector extraction complete.
# 2025-11-03 23:54:03,501 - INFO - [IN _assign_sectors] - Assigning students to sectors...
# 2025-11-03 23:54:03,531 - INFO - [IN _assign_sectors] - Sector assignment complete.
# 2025-11-03 23:54:03,532 - INFO - [IN _group_students_by_speaker_availability] - Grouping students by sector based on speaker counts and group size...
# 2025-11-03 23:54:03,533 - INFO - [IN _group_students_by_speaker_availability] - Grouping complete.
# 2025-11-03 23:54:03,533 - INFO - [IN _update_dataframes_with_assignments] - Updating DataFrames with final assignments...
# 2025-11-03 23:54:03,542 - INFO - [IN _update_dataframes_with_assignments] - DataFrame updates complete.
# 2025-11-03 23:54:03,547 - INFO - [IN _write_to_excel] - Writing output to Excel file: output/student_assignments_20251103_235403.xlsx
# 2025-11-03 23:54:03,872 - INFO - [IN _write_to_excel] - Excel file writing complete.
# 2025-11-03 23:54:03,873 - INFO - [IN process] - Processing complete. Output saved to output/student_assignments_20251103_235403.xlsx
# --------------------------------------------------
# 🎉 Success! The process completed.
# The output file has been saved to: 'None specified, check default location'
# --------------------------------------------------
